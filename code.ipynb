# %% [markdown]
# # EDA

# %%
import pandas as pd

# Load the dataset
file_path = "../../pew_data/2023-24 RLS Public Use File Feb 19.csv"
df = pd.read_csv(file_path)

# Display basic info about the dataset
df.info()

# Show the first few rows
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36908 entries, 0 to 36907
# Columns: 654 entries, P_SUID to REPWT_500
# dtypes: float64(543), int64(111)
# memory usage: 184.2 MB
#      P_SUID  YEAR_FROM_CODATE  REGION  HAPPY  SATIS_A  SATIS_B  CHNG_A  \
# 0  10000040              2023     NaN      1        2        2       2
# 1  10000060              2023     NaN      1        2        1       1
# 2  10000140              2024     NaN      2        2        3       3
# 3  10000150              2023     NaN      3        3        3       2
# 4  10000160              2023     NaN      3        1        1       3
#
#    CHNG_B  CHNG_C  DIVRELPOP  ...    REPWT_491     REPWT_492     REPWT_493  \
# 0       3       2          2  ...  8637.197077   3197.889015   6477.569705
# 1       1       1          1  ...     0.000000  12887.026798      0.000000
# 2       1       1          1  ...  3495.132770      0.000000      0.000000
# ...

# %%
# Get summary statistics for numerical columns
summary_stats = df.describe()

# Print summary statistics
print(summary_stats)
# Out:
#              P_SUID  YEAR_FROM_CODATE  REGION         HAPPY       SATIS_A  \
# count  3.690800e+04      36908.000000     0.0  36908.000000  36908.000000
# mean   1.108331e+07       2023.136474     NaN      2.254118      2.777149
# std    6.217415e+05          0.343296     NaN      6.313749      4.797106
# min    1.000004e+07       2023.000000     NaN      1.000000      1.000000
# 25%    1.054500e+07       2023.000000     NaN      1.000000      2.000000
# 50%    1.108167e+07       2023.000000     NaN      2.000000      3.000000
# 75%    1.162270e+07       2023.000000     NaN      2.000000      3.000000
# max    1.215894e+07       2024.000000     NaN     99.000000     99.000000
#
#             SATIS_B        CHNG_A        CHNG_B        CHNG_C     DIVRELPOP  \
# count  36908.000000  36908.000000  36908.000000  36908.000000  36908.000000
# mean       2.641379      3.233635      2.091146      3.283705      2.580443
# ...

# %%
# Filter the dataset to exclude rows where the value is 99
df_exclude_refused = df[df != 99]

# Calculate summary statistics for the filtered DataFrame
summary_stats = df_exclude_refused.describe()

# Show the summary statistics
print(summary_stats)
# Out:
#              P_SUID  YEAR_FROM_CODATE  REGION         HAPPY       SATIS_A  \
# count  3.690800e+04      36908.000000     0.0  36753.000000  36820.000000
# mean   1.108331e+07       2023.136474     NaN      1.846108      2.547175
# std    6.217415e+05          0.343296     NaN      0.625029      0.940777
# min    1.000004e+07       2023.000000     NaN      1.000000      1.000000
# 25%    1.054500e+07       2023.000000     NaN      1.000000      2.000000
# 50%    1.108167e+07       2023.000000     NaN      2.000000      3.000000
# 75%    1.162270e+07       2023.000000     NaN      2.000000      3.000000
# max    1.215894e+07       2024.000000     NaN      3.000000      5.000000
#
#             SATIS_B        CHNG_A        CHNG_B        CHNG_C     DIVRELPOP  \
# count  36773.000000  36397.000000  36646.000000  36325.000000  36573.000000
# mean       2.287630      1.889112      1.398297      1.747502      1.697263
# ...

# %%
# Calculate the mean for a specific column, excluding 99
mean_happiness = df['HAPPY'][df['HAPPY'] != 99].mean()

print(f"Mean happiness (excluding 99): {mean_happiness}")
# Out:
# Mean happiness (excluding 99): 1.8461078007237504
